# %%
from dotenv import load_dotenv
import os

# .env 파일을 불러와서 환경 변수로 설정
load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
UPSTAGE_API_KEY = os.getenv("UPSTAGE_API_KEY")
print(UPSTAGE_API_KEY[30:])
print(OPENAI_API_KEY[:5])
# Out:
# 5L
# sk-pr

# %% [markdown]
# #### 문제 3-1 :  콘텐츠분쟁해결 RAG 시스템

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_upstage import ChatUpstage
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate
from langchain_upstage import UpstageEmbeddings

loader = PyPDFLoader('../data/콘텐츠분쟁해결_사례.pdf')
documents = loader.load()

# %%
def main():
    """
    콘텐츠 분쟁 해결 사례집을 기반으로 법률 자문을 제공하는 RAG 시스템을 구축하고 실행합니다.
    """
    # .env 파일에서 환경 변수 로드
    load_dotenv()

    # UPSTAGE_API_KEY 환경 변수 확인
    if "UPSTAGE_API_KEY" not in os.environ:
        print("에러: UPSTAGE_API_KEY 환경 변수가 설정되지 않았습니다.")
        print("'.env' 파일에 UPSTAGE_API_KEY='your_api_key' 형식으로 키를 추가해주세요.")
        return

    print("="*50)
    print("콘텐츠 분쟁 해결 RAG 시스템 - 실습 시작")
    print("="*50)

    # # 0단계: 문서 로드
    # # PDF 파일을 로드합니다. 파일 경로는 실제 위치에 맞게 수정해야 할 수 있습니다.
    # try:
    #     loader = PyPDFLoader('./콘텐츠분쟁해결_사례.pdf')
    #     documents = loader.load()
    #     print(f"\n[0단계: 문서 로드] 성공: 총 {len(documents)} 페이지")
    # except Exception as e:
    #     print(f"\n[0단계: 문서 로드] 실패: PDF 파일을 찾을 수 없거나 로드할 수 없습니다.")
    #     print("  - 현재 디렉토리에 '콘텐츠분쟁해결_사례.pdf' 파일이 있는지 확인하세요.")
    #     print(f"  - 상세 오류: {e}")
    #     return

    # 1단계: 문서 분할 설정
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=1500,
        chunk_overlap=300,
        separators=[
            "\n【사건개요】",
            "\n【쟁점사항】",
            "\n【처리경위】",
            "\n【처리결과】",
            "\n■", "\n\n", "\n", ".", " ", ""
        ]
    )
    docs = text_splitter.split_documents(documents)
    print(f"[1단계: 문서 분할] 완료: {len(docs)}개의 문서 조각(chunk) 생성")

    # 2단계: 임베딩 모델 설정
    embeddings = UpstageEmbeddings(model="solar-embedding-1-large")
    print("[2단계: 임베딩 모델] 설정 완료: solar-embedding-1-large")

    # 벡터 스토어 생성 (FAISS 사용)
    # 로드된 문서 조각들을 임베딩하여 FAISS 벡터 스토어에 저장합니다.
    try:
        vectorstore = FAISS.from_documents(docs, embeddings)
        print("[벡터 스토어] 생성 완료 (FAISS)")
    except Exception as e:
        print(f"[벡터 스토어] 생성 실패: {e}")
        return


    # 3단계: 검색기(Retriever) 설정
    retriever = vectorstore.as_retriever(
        search_type="similarity",
        search_kwargs={"k": 5}
    )
    print("[3단계: 검색기 설정] 완료: 유사도 기반, 상위 5개 결과 검색")

    # 4단계: LLM 설정
    llm = ChatUpstage(
        model="solar-pro",
        temperature=0.5
    )
    print("[4단계: LLM 설정] 완료: solar-1-mini (temperature=0.2)")


    # 5단계: 법률 자문 프롬프트 작성
    prompt_template = """
    당신은 콘텐츠 분야 전문 법률 자문가입니다.
    아래 분쟁조정 사례들을 바탕으로 정확하고 전문적인 법률 조언을 제공해주세요.

    관련 분쟁사례:
    {context}

    상담 내용: {question}

    답변 가이드라인:
    1. 사례를 근거로 답변하세요.
    2. 관련 법령을 명시하세요.  
    3. 단계별 해결방안을 제시하세요.
    4. 유사 사례를 참조하세요.
    5. 없는 정보는 "확인할 수 없습니다"라고 하세요.


    전문 법률 조언:"""

    prompt = PromptTemplate.from_template(prompt_template)
    print("[5단계: 프롬프트 작성] 완료: 법률 자문 프롬프트가 설정되었습니다.")

    # 6단계: QA 체인 생성
    qa_chain = RetrievalQA.from_chain_type(
        llm=llm,
        chain_type="stuff",
        retriever=retriever,
        chain_type_kwargs={"prompt": prompt},
        return_source_documents=True
    )
    print("[6단계: QA 체인 생성] 완료: RAG 파이프라인이 준비되었습니다.")

    # 7단계: 테스트 질문 작성
    test_questions = [
        "온라인 게임에서 시스템 오류로 아이템이 사라졌는데, 게임회사가 복구를 거부하고 있습니다. 어떻게 해결할 수 있나요?",
        "인터넷 강의를 중도 해지하려고 하는데 과도한 위약금을 요구받고 있습니다. 정당한가요?",
        "무료체험 후 자동으로 유료전환되어 요금이 청구되었습니다. 환불 가능한가요?",
        "미성년자가 부모 동의 없이 게임 아이템을 구매했습니다. 환불받을 수 있는 방법이 있나요?",
        "온라인 교육 서비스가 광고와 다르게 제공되어 계약을 해지하고 싶습니다. 가능한가요?"
    ]
    print(f"\n[7단계: 테스트 질문] {len(test_questions)}개의 테스트 질문이 준비되었습니다.")

    # 8단계: 분쟁 유형 분류 함수 (선택)
    def classify_dispute_type(query):
        game_keywords = ["게임", "아이템", "계정", "캐릭터", "레벨", "길드", "온라인게임"]
        elearning_keywords = ["강의", "온라인교육", "이러닝", "수강", "환불", "화상교육"]
        web_keywords = ["웹사이트", "무료체험", "자동결제", "구독", "사이트"]
        
        query_lower = query.lower()
        
        if any(keyword in query_lower for keyword in game_keywords):
            return "게임"
        elif any(keyword in query_lower for keyword in elearning_keywords):
            return "이러닝"
        elif any(keyword in query_lower for keyword in web_keywords):
            return "웹콘텐츠"
        else:
            return "기타"
    print("[8단계: 분류 함수] 분쟁 유형 분류 함수가 정의되었습니다.")

    # 테스트 질문 실행
    print("\n" + "="*50)
    print("테스트 질문에 대한 법률 자문을 시작합니다.")
    print("="*50 + "\n")

    for i, question in enumerate(test_questions, 1):
        print(f"--- 질문 {i} ---")
        
        # 8단계 함수 사용 예시
        dispute_type = classify_dispute_type(question)
        print(f"상담 내용: {question}")
        print(f"(분류된 분쟁 유형: {dispute_type})")
        print("\n[AI 법률 자문가 답변]")
        print("답변 생성 중...")

        try:
            # QA 체인 실행
            result = qa_chain.invoke({"query": question})
            
            # 결과 출력
            print(result["result"].strip())
            
            # 참조한 소스 문서 출력
            source_docs = result.get("source_documents", [])
            if source_docs:
                print("\n[참조한 사례 정보]")
                for doc_num, doc in enumerate(source_docs, 1):
                    # page_content의 첫 100자만 미리보기로 표시
                    content_preview = doc.page_content.strip().replace('\n', ' ')[:100]
                    page_number = doc.metadata.get('page', 'N/A')
                    print(f"  - 문서 {doc_num} (Page: {page_number}): \"{content_preview}...\"")

        except Exception as e:
            print(f"  오류 발생: 답변을 생성하는 동안 문제가 발생했습니다.")
            print(f"  상세 오류: {e}")

        print("\n" + "-"*20 + "\n")

if __name__ == '__main__':
    main()
# Out:
# ==================================================
# 콘텐츠 분쟁 해결 RAG 시스템 - 실습 시작
# ==================================================
# [1단계: 문서 분할] 완료: 104개의 문서 조각(chunk) 생성
# [2단계: 임베딩 모델] 설정 완료: solar-embedding-1-large
# [벡터 스토어] 생성 완료 (FAISS)
# [3단계: 검색기 설정] 완료: 유사도 기반, 상위 5개 결과 검색
# [4단계: LLM 설정] 완료: solar-1-mini (temperature=0.2)
# [5단계: 프롬프트 작성] 완료: 법률 자문 프롬프트가 설정되었습니다.
# [6단계: QA 체인 생성] 완료: RAG 파이프라인이 준비되었습니다.
#
# [7단계: 테스트 질문] 5개의 테스트 질문이 준비되었습니다.
# [8단계: 분류 함수] 분쟁 유형 분류 함수가 정의되었습니다.
#
# ==================================================
# 테스트 질문에 대한 법률 자문을 시작합니다.
# ==================================================
#
# --- 질문 1 ---
# 상담 내용: 온라인 게임에서 시스템 오류로 아이템이 사라졌는데, 게임회사가 복구를 거부하고 있습니다. 어떻게 해결할 수 있나요?
# (분류된 분쟁 유형: 게임)
#
# [AI 법률 자문가 답변]
# 답변 생성 중...
# ### 전문 법률 조언: 온라인 게임 시스템 오류로 인한 아이템 복구 거부 시 해결방안
#
# #### 1. **사례 분석 및 법적 근거**
# 제공된 분쟁조정 사례를 종합하면, 시스템 오류로 인한 아이템 복구 문제는 다음 요소에 따라 해결 여부가 결정됩니다:
# - **(1) 시스템 오류의 객관적 입증**: 게임사의 기술적 결함이 확인되어야 함 (2009년 사례 참조).
# - **(2) 계정 소유권**: 명의자와 실소유자가 일치해야 복구 가능성 높음 (2006년 사례 참조).
# - **(3) 게임사의 약관 조항**: 대부분의 게임사는 "아이템의 소유권 귀속" 및 "복구 불가" 조항을 약관에 명시함.
#
# **관련 법령**:
# - **민법 제250조(도품·유실물 특례)**: 아이템이 "금전" 또는 "디지털 콘텐츠"로 해석될 경우 적용되지 않을 수 있음.
# - **전자상거래법 제17조(청약철회 등)**: 디지털 콘텐츠는 제공이 시작된 경우 청약철회 제한 가능.
# - **약관의 규제에 관한 법률 제6조(불공정 약관 무효)**: 게임사의 복구 거부 조항이 지나치게 불공정할 경우 무효 가능성 있음.
#
# ---
#
# #### 2. **단계별 해결방안**
#
# **1단계: 시스템 오류 증거 수집**
# - 게임 내 접속 기록, 오류 스크린샷, 고객센터 문의 내역 등 보관.
# - 동일 시간대 다른 유저의 유사 피해 사례 조사 (2009년 사례에서 타 유저 피해 없음으로 복구 거부됨).
#
# **2단계: 게임사에 공식 문의 및 이의제기**
# - **계정 소유권 확인**: 명의자와 실소유자가 다를 경우, 본인임을 증명할 수 있는 자료(결제 내역, 인증 기록) 제출.
# - **복구 요청서 제출**: 게임사의 공식 채널(이메일, 고객센터)을 통해 서면으로 요청.
# - **약관 검토**: "아이템 소유권 귀속" 및 "오류 발생 시 책임" 조항 확인.
#
# **3단계: 소비자분쟁조정위원회 신청**
# - 게임사가 복구를 거부할 경우, **한국소비자원** 또는 **콘텐츠분쟁조정위원회**에 조정 신청.
# - **필요 서류**:
#   - 게임 계정 정보, 아이템 소멸 시점 증명 자료.
#   - 게임사와의 대화 기록(채팅, 이메일).
#   - 결제 내역(아이템 구매 증명).
#
# **4단계: 소송 제기 (최후의 수단)**
# - **청구 근거**:
#   - **채무불이행(민법 제390조)**: 게임사가 서비스 제공 의무를 위반한 경우.
#   - **불공정 약관 무효(약관규제법 제6조)**: 복구 거부가 불합리한 경우.
# - **주의점**: 디지털 아이템의 재산적 가치가 인정되기 어려울 수 있음.
#
# ---
#
# #### 3. **유사 사례 참조**
# - **2006년 사례**: 계정 명의자 불일치로 복구 거부. → 실소유자 증명 필요.
# - **2009년 사례**: 시스템 오류 미입증으로 복구 불가. → 객관적 증거 확보 필수.
# - **2006년 프로그램 오류 사례**: 게임사가 오류 인정 후 복구. → 게임사의 자발적 조치 가능성.
#
# ---
#
# #### 4. **추가 권고사항**
# - **게임사 약관 주의**: 대부분의 게임사는 "아이템의 소유권 귀속" 및 "복구 불가" 조항을 명시하므로, 가입 시 반드시 확인.
# - **현금거래 금지**: 계정 공유 또는 현금거래는 복구 요청 시 불이익 요인 (2006년 사례 참조).
# - **디지털 자산의 한계**: 현행법상 가상 아이템의 재산적 가치가 제한적일 수 있으므로, 과도한 기대는 지양.
#
# > **결론**: 시스템 오류 입증 및 계정 소유권 확인 후 게임사에 공식 요청 → 거부 시 소비자분쟁조정위원회에 조정 신청. 소송 시 성공 가능성은 증거에 크게 의존하므로 전문가 상담이 필요합니다.
#
# ※ 확인되지 않은 정보(예: 특정 게임사의 내부 규정)는 "확인할 수 없습니다"로 답변합니다.
#
# [참조한 사례 정보]
#   - 문서 1 (Page: 8): "1. 게임 3게임1 ■ 1-가-1) 한국소비자원 조정전 상담사례 2006_시스템 오류로 소멸된 아이템 복구 요구 【사건개요 】 신청인은 피신청인이 제공하는 온라인게임서비스를 이용하..."
#   - 문서 2 (Page: 28): "1. 게임 23■ 1-가-1) 한국소비자원 조정전 상담사례 2009_시스템 오류로 인한 손실 아이템 복구 요구 【사건개요 】 신청인은 2009. 9. 4 피신청인 프로그램 업데이트..."
#   - 문서 3 (Page: 2): "2009_ 인터넷 게임 계정 영구이용 제한조치 취소 요구···································· 1 9 2009_ 사용하지 않았으나 차감된 아이템 배상 요..."
#   - 문서 4 (Page: 9): "콘텐츠분쟁조정 법리 연구 2부 - 타 분쟁조정사례 조사 - 4■ 1-가-1) 한국소비자원 조정전 상담사례 2006_프로그램 오류로 소멸된 아이템 복구 요구 【사건개요 】 신청인은 ..."
#   - 문서 5 (Page: 10): "1. 게임 5■ 1-가-1) 한국소비자원 조정전 상담사례 2007_인터넷게임서비스 아이템 복구 요구 【사건개요 】 신청인은 피신청인의 인터넷게임서비스를 이용자이다 . 2007. 1..."
#
# --------------------
#
# --- 질문 2 ---
# 상담 내용: 인터넷 강의를 중도 해지하려고 하는데 과도한 위약금을 요구받고 있습니다. 정당한가요?
# (분류된 분쟁 유형: 이러닝)
#
# [AI 법률 자문가 답변]
# 답변 생성 중...
# ### 전문 법률 조언: 인터넷 강의 중도 해지 시 과도한 위약금 요구 문제
#
# #### 1. **사례 근거 및 관련 법령**
# 제시된 분쟁사례(2007~2010년 한국소비자원 조정결정례)와 관련 법령에 따르면, **과도한 위약금 요구는 부당**하며, 다음과 같은 기준이 적용됩니다.
#
# - **방문판매 등에 관한 법률 제29조(계약 해지)**
#   - 계속거래(1개월 이상 서비스 제공) 계약 해지 시, **실제 이용일수 + 총 이용금액의 10% 이내**만 공제 가능합니다.
#   - 위약금이 "현저하게 초과"하는 경우 무효입니다(방판법 제30조).
#
# - **소비자분쟁해결기준(공정위 고시, 인터넷콘텐츠업)**
#   - 해지일까지의 **이용일수 × 월 이용료** + **총 금액의 10% 이내** 공제 후 환급이 원칙입니다.
#   - 사은품은 미사용 시 반환하거나 해당 비용을 공제할 수 있습니다.
#
# - **소비자기본법 시행령 제10조**
#   - 계약서에 명시된 **실제 지불 금액**을 기준으로 환급액을 산정해야 합니다.
#
# ---
#
# #### 2. **단계별 해결방안**
#
# **1단계: 계약서 확인**
#   - 계약서에 명시된 **총 계약금액**, **월 이용료**, **해지 조건**, **위약금 조항**을 확인합니다.
#   - *예시 사례*: 2008년 사례에서 피신청인이 계약서 금액(1,560,000원)과 실제 지불액(1,050,000원)을 달리 적용한 것은 부당하다고 판단되었습니다.
#
# **2단계: 이용 기간 및 비용 계산**
#   - **이용일수**: 서비스 개통일부터 해지일까지의 실제 이용 기간을 산정합니다.
#     - *예시 사례*: 2010년 화상 강의 사례에서는 서비스 개통일(5. 27.)을 기준으로 이용 기간을 계산했습니다.
#   - **공제 가능 금액**:
#     - `(이용일수 ÷ 총 계약 기간) × 총 금액` + `총 금액의 10% 이내`
#     - *예시*: 12개월 계약 중 3개월 이용 시 → (3/12 × 총 금액) + 10%
#
# **3단계: 부당 공제 항목 검토**
#   - **위약금, 컨텐츠 비용, 가입비** 등은 원칙적으로 공제 대상이 아닙니다.
#     - *예시 사례*: 2007년 사례에서 피신청인이 "화상교육비"를 공제한 것은 부당하다고 판단되었습니다.
#   - 단, **사은품 비용**은 미사용 시 반환하거나 공제 가능합니다.
#
# **4단계: 증거 수집 및 협상**
#   - **이용 기록**(접속 로그, 결제 내역), **해지 통보 증거**(내용증명, 이메일), **계약서**를 확보합니다.
#   - 사업자에게 **소비자분쟁해결기준**에 따른 환급을 요구합니다.
#
# **5단계: 분쟁 조정 신청**
#   - 협상이 실패할 경우, **한국소비자원** 또는 **소비자분쟁조정위원회**에 조정을 신청합니다.
#     - *예시*: 2010년 사례에서 내용증명 해지 통보 후 조정 절차가 진행되었습니다.
#
# ---
#
# #### 3. **유사 사례 참조**
# - **2007년 중도해지 사례**: 위약금 1,632,000원 공제 주장은 부당 → 이용일수 + 10% 기준 환급 결정.
# - **2008년 환급 요구 사례**: 계약서 금액과 실제 지불액 불일치 시 실제 금액 기준으로 환급.
# - **2010년 화상 강의 사례**: 서비스 개통일을 이용 시작일로 인정해 공제 기간 산정.
#
# ---
#
# #### 4. **주의사항**
# - **구두 해지 통보**는 증거력이 약하므로 **내용증명** 또는 **이메일**로 해지 의사를 명시해야 합니다.
# - 사업자에게 **계약서 교부 의무**(방판법 제7조) 위반 시 추가 피해 보상 가능성이 있습니다.
#
# > ✅ **결론**: 과도한 위약금 요구는 법적 기준 위반입니다. 계약서, 이용 기록, 해지 증거를 바탕으로 소비자분쟁해결기준에 따른 환급을 요구하시기 바랍니다. 분쟁 조정 시 전문가의 도움을 받는 것이 유리합니다.
#
# ---
# **확인 불가 사항**:
# - 특정 사업자의 내부 약관 또는 추가 약정 내용은 확인할 수 없습니다. 계약서 또는 이용 약관을 반드시 검토하세요.
#
# [참조한 사례 정보]
#   - 문서 1 (Page: 3): "2007_ 온라인통신교육서비스 대금 환급 요구2················································· 5 5 2007_ 인터넷교육서비스 중도해지 ..."
#   - 문서 2 (Page: 62): "2. 이러닝 57■ 2-가 한국소비자원 조정결정례 2007_인터넷교육서비스 중도해지 요구 【사건개요 】 청구인은 2006. 2. 8. 피청구인이 운영하는 인터넷교육서비스를 청구인의..."
#   - 문서 3 (Page: 60): "2. 이러닝 55■ 2-가 한국소비자원 조정결정례 2007_온라인통신교육서비스 대금 환급 요구2 【사건개요 】 청구인은 2006. 10. 30. 자신의 자녀가 컴퓨터통신교육서비스를..."
#   - 문서 4 (Page: 72): "2. 이러닝 67■ 2-가 한국소비자원 조정결정례 2010_인터넷 화상 강의 수강계약 해지에 따른 환급 요구 【사건개요 】 신청인은 신청인의 자녀를 위하여 2009. 5. 13 피..."
#   - 문서 5 (Page: 66): "2. 이러닝 61■ 2-가 한국소비자원 조정결정례 2008_온라인통신교육서비스 이용료 환급 요구2 【사건개요 】 신청인은 2007. 11. 10. 자녀(중학교 1년) 교육을 위해 ..."
#
# --------------------
#
# --- 질문 3 ---
# 상담 내용: 무료체험 후 자동으로 유료전환되어 요금이 청구되었습니다. 환불 가능한가요?
# (분류된 분쟁 유형: 이러닝)
#
# [AI 법률 자문가 답변]
# 답변 생성 중...
# ### 전문 법률 조언: 무료체험 후 자동 유료전환 및 환급 요구 사안
#
# #### 1. **사례 근거 및 법적 쟁점**
# 제공된 분쟁사례(2010_무료 이벤트 후 자동 소액 결제 요금 환급요구, 2006_무료 광고 후 서비스 이용요금 청구)와 관련해, **"계약 체결 시 중요내용 명시·고지의무 위반"**이 핵심 쟁점입니다.
# - **사례 1 (95■ 3-가)**: 무료 이벤트 기간 내 해지하지 않을 경우 유료 전환된다는 내용이 **작은 글씨로 표시**되어 소비자가 인지하기 어려웠고, **핸드폰 인증 과정에서 추가 고지가 없어** 사업자의 책임이 50% 인정되었습니다.
# - **사례 2 (97■ 3-나)**: 무료 광고로 유인한 후 **유료 결제 사실을 명확히 고지하지 않아** 소비자보호 법규 위반 소지가 있음을 지적했습니다.
#
# #### 2. **관련 법령**
# - **약관의 규제에 관한 법률 제3조(작성 및 설명의무)**: 사업자는 계약 내용에 대해 **명확히 설명할 의무**가 있으며, 중요 사항을 소비자가 쉽게 알 수 있도록 표시해야 합니다.
# - **소비자기본법 제18조(소비자분쟁해결기준)**: 무료체험 후 자동 유료전환 시 **사전 동의 및 명확한 고지**가 없을 경우, 계약 취소 또는 부분 환급이 가능합니다.
# - **표시·광고의 공정화에 관한 법률**: 허위·과장 광고 또는 필수 정보 누락 시 시정조치나 환급 책임이 발생할 수 있습니다.
#
# #### 3. **단계별 해결방안**
# **(1) 계약 내용 확인**
# - 이용약관 또는 이벤트 페이지에서 **"자동 유료전환"** 관련 조항이 명시되어 있는지 확인합니다.
# - 고지 내용이 **명확하고 눈에 띄는 위치**에 있었는지, **글씨 크기·색상** 등이 충분한지 검토합니다.
#
# **(2) 환급 가능성 판단**
# - **고지 미비** 또는 **동의 절차 생략**이 확인되면, **부분 환급(사례 1 기준 50%)**을 요구할 수 있습니다.
# - **이용하지 않은 기간**에 대해서는 전액 환급을 주장할 수 있습니다(소비자기본법 제18조).
#
# **(3) 사업자와의 협의**
# - **증거 확보**: 이용내역, 결제 영수증, 이벤트 페이지 스크린샷 등을 보관합니다.
# - **공식 채널(이메일·전화)**로 환급 요청을 하고, **조정기관(한국소비자원, 전자거래분쟁조정위원회)**에 분쟁조정을 신청할 수 있습니다.
#
# **(4) 법적 조치**
# - 협의가 불가능할 경우, **소비자분쟁조정위원회**에 조정을 신청하거나, **민사소송**을 통해 계약 취소 및 손해배상을 청구할 수 있습니다.
#
# #### 4. **유사 사례 참조**
# - **공정위 시정조치(2009. 9. 27.)**: 무료체험 이벤트 후 유료전환을 강제하는 약관은 **무효**로 판단될 수 있습니다.
# - **자율분쟁조정위원회 사례**: 중도 해지 시 위약금을 부과하거나 해지를 어렵게 하는 조항은 **부당하게 소비자에게 불이익**을 주는 것으로 무효 처리되었습니다.
#
# #### 5. **추가 권고 사항**
# - **무료체험 가입 시** "자동 유료전환" 여부를 반드시 확인하고, **이용약관 전체를 정독**해야 합니다.
# - **결제 인증 번호 입력** 시 유료 전환 동의로 간주될 수 있으므로 주의가 필요합니다.
#
# ### 결론
# **"고지 미비" 또는 "동의 절차 생략"이 증명될 경우, 부분 환급 또는 계약 취소가 가능합니다.** 다만, 소비자가 이용약관에 동의한 사실이나 장기간 결제 사실을 인지하지 못한 점 등이 책임 분담에 영향을 줄 수 있으므로, **증거 수집과 전문가 상담**을 권장합니다.
#
# > ※ 참고: 정확한 책임 비율은 개별 사안의 증거(예: 고지의 명확성, 소비자의 주의 의무)에 따라 달라질 수 있습니다.
#
# [참조한 사례 정보]
#   - 문서 1 (Page: 100): "3. 기타(웹) 95■ 3-가 한국소비자원 조정결정례 2010_무료 이벤트 후 자동 소액 결제 요금 환급요구 【사건개요 】 신청인은 2008. 12. 29. 피신청인 1이 운영하는..."
#   - 문서 2 (Page: 101): "콘텐츠분쟁조정 법리 연구 2부 - 타 분쟁조정사례 조사 - 96받는 것과는 달리 무료 이벤트 참여를 위한 회원 가입 시 인증번호를 부여받게 되어있다는  점, 계약 해지를 통지하지 ..."
#   - 문서 3 (Page: 102): "3. 기타(웹) 97■ 3-나 전자거래분쟁조정위원회 조정전합의 사례 2006_무료 광고 후 서비스 이용요금 청구 【사건개요 】 신청인은 한 사이버몰에서 무료 핸드폰 이용권 이벤트에..."
#   - 문서 4 (Page: 103): "콘텐츠분쟁조정 법리 연구 2부 - 타 분쟁조정사례 조사 - 98뿐만 아니라 이용자가 가입 후 해지를 원할 때 일정기간 해지를 못하게 한다거나 해지 신청  상담 전화번호를 부정확하게..."
#   - 문서 5 (Page: 4): "콘텐츠분쟁조정 법리 연구 제2부 - 타 분쟁조정사례 조사 - 나. 자율분쟁조정위원회 2008_ 인터넷 화상과외 중도계약해지 ·······························..."
#
# --------------------
#
# --- 질문 4 ---
# 상담 내용: 미성년자가 부모 동의 없이 게임 아이템을 구매했습니다. 환불받을 수 있는 방법이 있나요?
# (분류된 분쟁 유형: 게임)
#
# [AI 법률 자문가 답변]
# 답변 생성 중...
# ### 전문 법률 조언: 미성년자의 부모 동의 없이 게임 아이템 구매 시 환불 가능성
#
# #### 1. **사례 및 관련 법령 근거**
# - **사례 1 (2008_부당결제대금 반환 청구)**:
#   - 미성년자가 타인 명의를 도용하여 게임 아이템을 구매한 경우, **민법 제5조(미성년자의 능력)**에 따라 부모 동의 없는 계약은 취소 가능합니다.
#   - 그러나 **민법 제17조(무능력자의 사술)**에 따라 미성년자가 성인으로 속이기 위해 사술(거짓말, 타인 명의 도용 등)을 사용한 경우, 계약 취소가 제한될 수 있습니다.
#   - 해당 사례에서는 피신청인(게임사)이 실명 인증 시스템을 미흡하게 운영한 점을 고려해 **신청인(부모) 65%, 피신청인 35%**의 손해 분담을 권고했습니다.
#
# - **사례 2 (2006_미성년자 단독 결제 취소 청구)**:
#   - 미성년자가 성인 아이디로 결제한 경우, 게임사는 사술로 간주해 환불을 거부할 수 있으나, **미성년자 본인 명의 결제 부분만 취소**해야 합니다.
#   - 본 사례에서는 피신청인이 미성년자 명의 결제 금액을 환불하는 것으로 합의했습니다.
#
# - **사례 3 (2008_미성년자 신용카드 부정사용)**:
#   - 미성년자가 부모 명의를 도용해 고액 결제한 경우, **민법 제5조**에 따라 계약 취소가 가능하지만, 게임사가 성인 인증 절차(전화 확인, 보안 시스템)를 이행한 경우 책임이 경감될 수 있습니다.
#   - 해당 사례에서는 게임머니 현금화 목적 등 고의성이 인정되며, 피신청인의 부분적 책임이 인정되었습니다.
#
# #### 2. **관련 법령**
# - **민법 제5조(미성년자의 능력)**: 미성년자가 법정대리인의 동의 없이 체결한 계약은 취소할 수 있습니다.
# - **민법 제17조(무능력자의 사술)**: 미성년자가 사술(거짓말, 명의 도용 등)로 상대방으로 하여금 성년자로 믿게 한 경우, 계약을 취소할 수 없습니다.
# - **전자상거래 등에서의 소비자보호에 관한 법률 제17조**: 미성년자의 계약 취소 권한을 명시합니다.
#
# #### 3. **단계별 해결 방안**
# **(1) 계약 취소 가능성 검토**
# - **명의 도용 여부**: 자녀가 본인 명의가 아닌 타인(부모 포함) 명의를 사용했다면, 게임사는 **사술 여부**를 입증해야 합니다.
#   - 예: 전화 확인 시 성인으로 주장, 보안 절차(카드 비밀번호, ISP 인증)를 통과했다면 사술로 간주될 수 있습니다.
# - **부모 동의 없음**: 미성년자가 단독으로 결제했다면, 원칙적으로 계약 취소 가능합니다.
#
# **(2) 증거 수집**
# - 결제 내역(신용카드 명세서, 게임 로그), 게임사와의 통화 기록, 자녀의 연령 증명(가족관계증명서) 등을 확보합니다.
# - 게임사가 실명 인증 또는 성인 확인 절차를 이행했는지 확인합니다.
#
# **(3) 게임사에 환불 요청**
# - **공식 채널(이메일, 고객센터)**로 계약 취소 및 환불을 요청합니다.
# - **전자거래분쟁조정위원회(KCA)**에 조정을 신청할 수 있습니다.
#   - 조정 시 게임사의 시스템 미비(실명 인증 생략, 미성년자 결제 허용)가 입증되면 부분적 환불이 가능합니다.
#
# **(4) 분쟁 조정 또는 소송**
# - 게임사가 환불을 거부할 경우, **소비자원** 또는 **법원**에 소송을 제기할 수 있습니다.
#   - 과거 사례에서는 게임사의 책임 비율(30~35%)이 인정된 바 있습니다.
#
# #### 4. **유사 사례 참조**
# - **타인 명의 도용**: 게임사가 실명 인증 시스템을 운영하지 않았다면, 부모 책임 비율이 높아집니다(사례 1).
# - **성인 인증 절차 이행**: 게임사가 전화 확인 등으로 성인임을 확인했다면, 환불 범위가 축소될 수 있습니다(사례 3).
# - **미성년자 본인 명의 결제**: 해당 부분만 취소 가능합니다(사례 2).
#
# #### 5. **주의 사항**
# - 게임머니가 이미 사용되거나 현금화된 경우, 환불이 어려울 수 있습니다.
# - 자녀의 고의성(현금화 목적 등)이 입증되면, 부모의 책임이 증가할 수 있습니다.
#
# ### 결론
# **"미성년자의 부모 동의 없는 게임 아이템 구매는 원칙적으로 취소 가능하나, 게임사의 인증 절차 이행 여부 및 자녀의 사술 사용 여부에 따라 환불 범위가 달라질 수 있습니다. 증거 수집 후 게임사와 협의하거나 전자거래분쟁조정위원회에 조정을 신청하는 것이 효과적입니다."**
#
# > ✅ **추천 조치**:
# > 1. 게임사에 공식 환불 요청서 발송
# > 2. 결제 내역 및 통화 기록 등 증거 확보
# > 3. 소비자분쟁조정위원회(www.kca.go.kr) 또는 1372 소비자상담센터 문의
#
# [참조한 사례 정보]
#   - 문서 1 (Page: 50): "1. 게임 45■ 1-나 전자거래분쟁조정위원회 조정결정례 2008_부당결제대금 반환 청구 【사건개요 】 신청인의 자녀는 2004. 4. 22. 피신청인이 운영하는 게임 사이트에 가..."
#   - 문서 2 (Page: 43): "콘텐츠분쟁조정 법리 연구 2부 - 타 분쟁조정사례 조사 - 38■ 1-나 전자거래분쟁조정위원회 조정결정례 2006_미성년자 단독으로 한 결제 취소 청구 【사건개요 】 신청인은 본인..."
#   - 문서 3 (Page: 51): "콘텐츠분쟁조정 법리 연구 2부 - 타 분쟁조정사례 조사 - 46라 구입대금의 지급 책임도 신청인의 미성년자 자녀에게 있다고 할 것이며 , 또한 신청인의 자녀 의 아이템 구입행위가 ..."
#   - 문서 4 (Page: 52): "1. 게임 47신청인의 미성년 아들이 신청인의 이름을 도용하여 피신청인사 사이트에 회원 가입 후 2008. 9.  23.부터 같은 해 9. 25.까지 주(A)사의 대표적 게임인 0..."
#   - 문서 5 (Page: 53): "콘텐츠분쟁조정 법리 연구 2부 - 타 분쟁조정사례 조사 - 48 - 피신청인   ㆍ 피신청인은 구매당시 구매자에게 전화를 하였을 당시 전화를 받은 자는 자신을 24세의 남성으로  ..."
#
# --------------------
#
# --- 질문 5 ---
# 상담 내용: 온라인 교육 서비스가 광고와 다르게 제공되어 계약을 해지하고 싶습니다. 가능한가요?
# (분류된 분쟁 유형: 기타)
#
# [AI 법률 자문가 답변]
# 답변 생성 중...
# ### 전문 법률 조언: 온라인 교육 서비스 계약 해지 및 환급 요구 관련
#
# #### 1. **계약 해지 가능성 및 법적 근거**
# - **계약 해지 권리**:
#   - 「방문판매 등에 관한 법률」 제29조에 따라 **계속적 거래(1년 단위 온라인 교육 서비스)** 계약은 소비자가 언제든지 해지할 수 있습니다.
#   - 광고와 실제 서비스가 상이할 경우, 「민법」 제575조(하자담보책임) 또는 「전자상거래 등에서의 소비자보호에 관한 법률」 제14조(청약철회)를 근거로 계약 해지가 가능합니다.
#     - *예시*: 2010년 사례(화상불량 강의)에서는 서비스 미제공으로 중도 해지 및 환급이 인정되었습니다.
#
# #### 2. **환급금 산정 기준**
# - **법정 환급 원칙**:
#   - 「방문판매 등에 관한 법률」 제30조는 **과도한 위약금 청구를 금지**하며, 소비자분쟁해결기준(공정위 고시)에 따라 환급금을 산정해야 합니다.
#     - **이용일수 공제**: 실제 이용한 기간에 해당하는 금액만 공제 가능(예: 3개월 이용 시 9개월 분 환급).
#     - **위약금 제한**: 총 이용요금의 **10% 이내**만 위약금으로 공제 가능(2007년 사례에서 10% 초과 공제 무효 판정).
#   - **부당 공제 항목 배제**:
#     - 교재비, 가입비, 사은품 비용 등은 계약서에 명시되지 않았거나 실제 제공되지 않은 경우 공제 불가(2007년 사례 참조).
#
# #### 3. **단계별 해결 방안**
# 1. **증거 수집**:
#    - 계약서, 광고 자료, 이용 내역(접속 로그), 서비스 미제공 증거(화면 캡처 등)를 확보합니다.
# 2. **사업자와의 협의**:
#    - 「소비자기본법」 제16조에 따른 **소비자분쟁해결기준**을 제시하며 환급을 요구합니다.
#    - *예시*: 2008년 사례에서 할인 전 금액 공제 주장은 기각되었습니다.
# 3. **분쟁 조정 신청**:
#    - 협의 실패 시 한국소비자원에 분쟁 조정을 신청합니다(「소비자기본법」 제60조).
#    - *유사 사례*: 2010년 사례에서 계약 해지 후 2/3 환급 요구가 인정되었습니다.
#
# #### 4. **주의 사항**
# - **계약서 확인**: 위약금 조항, 환급 조건이 명시되었는지 확인합니다.
# - **광고와의 차이 증명**: 서비스 하자 또는 허위광고를 입증할 수 있어야 합니다.
# - **기한 준수**: 계약 해지 통보 후 **즉시 이용 중단**해야 추가 이용기간 공제를 방지합니다.
#
# #### 5. **유사 사례 참조**
# - **2007년 사례**: 위약금 10% 초과 공제 무효.
# - **2008년 사례**: 할인 전 금액 공제 불가.
# - **2010년 사례**: 서비스 미제공 시 전액 환급 가능.
#
# > **결론**: 광고와 다른 서비스 제공 시 계약 해지 및 환급이 가능하며, 환급금 산정 시 법정 기준을 준수해야 합니다. 사업자와의 협의가 어려울 경우 한국소비자원에 조정을 신청하는 것이 효과적입니다.
#
# ※ 정확한 환급액 산정을 위해 **계약서 및 이용 내역**을 반드시 확인하시기 바랍니다. 추가 정보가 필요한 경우 한국소비자원(1372) 또는 법률 전문가와 상담하세요.
#
# [참조한 사례 정보]
#   - 문서 1 (Page: 3): "2007_ 온라인통신교육서비스 대금 환급 요구2················································· 5 5 2007_ 인터넷교육서비스 중도해지 ..."
#   - 문서 2 (Page: 74): "2. 이러닝 69■ 2-가 한국소비자원 조정결정례 2010_온라인교육 서비스 계약 해지에 따른 이용요금 환급 요구 【사건개요 】 신청인은 2009. 11. 27. 피신청인과 1년 ..."
#   - 문서 3 (Page: 64): "2. 이러닝 59■ 2-가 한국소비자원 조정결정례 2008_온라인 통신교육서비스 이용료 환급 요구 【사건개요 】 신청인은 2007. 8. 8. 피신청인과 신청인 자녀(고등학생 )가..."
#   - 문서 4 (Page: 60): "2. 이러닝 55■ 2-가 한국소비자원 조정결정례 2007_온라인통신교육서비스 대금 환급 요구2 【사건개요 】 청구인은 2006. 10. 30. 자신의 자녀가 컴퓨터통신교육서비스를..."
#   - 문서 5 (Page: 62): "2. 이러닝 57■ 2-가 한국소비자원 조정결정례 2007_인터넷교육서비스 중도해지 요구 【사건개요 】 청구인은 2006. 2. 8. 피청구인이 운영하는 인터넷교육서비스를 청구인의..."
#
# --------------------
