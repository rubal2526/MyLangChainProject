# %% [markdown]
# ### 1) 라이브러리 설치

# %%
# poetry add pypdf=">=4.2.0,<5.0.0"
# poetry add langchain-upstage
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### PyPDFLoader 간단한 예제

# %%
from dotenv import load_dotenv
import os

# .env 파일을 불러와서 환경 변수로 설정
load_dotenv()

UPSTAGE_API_KEY = os.getenv("UPSTAGE_API_KEY")
print(UPSTAGE_API_KEY[30:])
# Out:
# 5L

# %% [markdown]
# #### Upstage 를 사용한 RAG
# * ChatUpstage
# * UpstageEmbeddings
# * UpstageDocumentParseLoader

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_upstage import ChatUpstage
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate
from langchain_upstage import UpstageEmbeddings

print("==> 1. 문서 로딩 → PDF 읽기...")
file_path = "../data/tutorial-korean.pdf"
loader = PyPDFLoader('../data/tutorial-korean.pdf')
documents = loader.load()
print(f"  총 {len(documents)}페이지 로드 완료")
# Out:
# ==> 1. 문서 로딩 → PDF 읽기...
#   총 39페이지 로드 완료

# %%
print("==> 2. 문서 분할 → 작은 청크로 나누기")
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,        # 청크 크기 (한국어 최적화)
    chunk_overlap=200,      # 중복 부분 (맥락 보존)
    separators=["\n\n", "\n", ".", " ", ""] # 자연스러운 분할을 위한 구분자
)

chunks = text_splitter.split_documents(documents)
print(f"  {len(chunks)}개 청크 생성 완료")
print(f"  평균 청크 길이: {sum(len(chunk.page_content) for chunk in chunks) / len(chunks):.0f}자")

print("==> 3. 벡터화 → 임베딩으로 변환")
embeddings = UpstageEmbeddings(model="solar-embedding-1-large")

print("==> 4. 저장 → FAISS 벡터스토어에 저장")
vectorstore = FAISS.from_documents(chunks, embeddings)
print(f" FAISS 벡터스토어 생성 완료 ({len(chunks)}개 벡터)")
# 로컬 파일로 저장
vectorstore.save_local("faiss_index_upstage")

print("===> 5. 검색 → 질문과 유사한 문서 찾기")
retriever = vectorstore.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 6}  # 상위 6개 관련 문서 검색
)
print(" Retriever 설정 완료")
# Out:
# ==> 2. 문서 분할 → 작은 청크로 나누기
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 print("==> 2. 문서 분할 → 작은 청크로 나누기")
# ----> 2 text_splitter = RecursiveCharacterTextSplitter(
#       3     chunk_size=1000,        # 청크 크기 (한국어 최적화)
#       4     chunk_overlap=200,      # 중복 부분 (맥락 보존)
#       5     separators=["\n\n", "\n", ".", " ", ""] # 자연스러운 분할을 위한 구분자
#       6 )
#       8 chunks = text_splitter.split_documents(documents)
#       9 print(f"  {len(chunks)}개 청크 생성 완료")
#
# NameError: name 'RecursiveCharacterTextSplitter' is not defined

# %%
print("===> 6. 생성 → LLM으로 답변 생성")
llm = ChatUpstage(
        model="solar-pro",
        base_url="https://api.upstage.ai/v1",
        temperature=0.5
    )
print(llm)
# Out:
# ===> 6. 생성 → LLM으로 답변 생성
# client=<openai.resources.chat.completions.completions.Completions object at 0x0000026162B36CF0> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x0000026162B36F90> model_name='solar-pro' temperature=0.5 model_kwargs={} upstage_api_key=SecretStr('**********') upstage_api_base='https://api.upstage.ai/v1'

# %%
# 한국어 최적화 프롬프트
prompt_template = """
당신은 BlueJ 프로그래밍 환경 전문가입니다. 
아래 문서 내용을 바탕으로 정확하고 친절한 답변을 제공해주세요.

문서 내용:
{context}

질문: {question}

답변 규칙:
1. 문서 내용만을 근거로 답변하세요
2. 단계별 설명이 필요하면 순서대로 작성하세요  
3. 구체적인 메뉴명, 버튼명을 포함하세요
4. 문서에 없는 정보는 "문서에서 찾을 수 없습니다"라고 하세요

답변:"""

prompt = PromptTemplate(
    template=prompt_template,
    input_variables=["context", "question"]
)
print(" 프롬프트 설정 완료")
print(prompt)
# Out:
#  프롬프트 설정 완료
# input_variables=['context', 'question'] input_types={} partial_variables={} template='\n당신은 BlueJ 프로그래밍 환경 전문가입니다. \n아래 문서 내용을 바탕으로 정확하고 친절한 답변을 제공해주세요.\n\n문서 내용:\n{context}\n\n질문: {question}\n\n답변 규칙:\n1. 문서 내용만을 근거로 답변하세요\n2. 단계별 설명이 필요하면 순서대로 작성하세요  \n3. 구체적인 메뉴명, 버튼명을 포함하세요\n4. 문서에 없는 정보는 "문서에서 찾을 수 없습니다"라고 하세요\n\n답변:'

# %%
# ===================================
# 7. QA 체인 생성
# ===================================
print("\n ===> 7.  QA 체인 생성...")
qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=retriever,
    chain_type_kwargs={"prompt": prompt},
    return_source_documents=True
)
print("  RAG 파이프라인 구축 완료!")

# ===================================
# 8. 테스트 질문들
# ===================================
test_questions = [
    "BlueJ에서 객체를 생성하는 방법은 무엇인가요?",
    "컴파일 오류가 발생했을 때 어떻게 확인할 수 있나요?", 
    "디버깅을 위해 중단점을 설정하는 방법을 알려주세요",
    "코드패드는 무엇이고 어떻게 사용하나요?",
    "애플릿을 만들고 실행하는 방법을 설명해주세요"
]

print("\n" + "=" * 60)
print(" RAG 시스템 테스트")
print("=" * 60)

# ===================================
# 9. 질문 및 답변 실행
# ===================================
for i, question in enumerate(test_questions, 1):
    print(f"\n【테스트 {i}/5】")
    print(f" 질문: {question}")
    print(" 답변 생성 중...")
    
    # RAG 실행
    result = qa_chain.invoke({"query": question})
    answer = result["result"]
    source_docs = result["source_documents"]
    
    print(f"\n 답변:")
    print("-" * 50)
    print(answer)
    
    # 참조 문서 정보
    print(f"\n 참조 문서:")
    for j, doc in enumerate(source_docs[:3], 1):
        page = doc.metadata.get('page', 'N/A')
        preview = doc.page_content[:80].replace('\n', ' ')
        print(f"   {j}. 페이지 {page}: {preview}...")
    
    print("\n" + "-" * 40)
# Out:
#  ===> 7.  QA 체인 생성...
#   RAG 파이프라인 구축 완료!
#
# ============================================================
#  RAG 시스템 테스트
# ============================================================
#
# 【테스트 1/5】
#  질문: BlueJ에서 객체를 생성하는 방법은 무엇인가요?
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# BlueJ에서 객체를 생성하는 방법은 다음과 같습니다. 문서 내용을 근거로 단계별로 설명드리겠습니다.
#
# ### 1. **일반 클래스 객체 생성 방법**
# 1. 메인 윈도우 중앙의 클래스 아이콘(예: `Person`, `Staff`)에서 **마우스 오른쪽 버튼 클릭** (Mac: `Ctrl+클릭`)
# 2. 팝업 메뉴에서 **생성자 함수** 선택
#    - 생성자 선택 시 객체 이름 입력 대화상자 표시
#    - 기본 이름(예: `staff_1`) 사용 가능 또는 직접 이름 입력 후 **OK 버튼** 클릭
# 3. 생성된 객체는 **오브젝트 벤치(Object Bench)**에 표시됨 (그림 4 참조)
#
# > **주의**: 추상 클래스(예: `Person` 클래스 아이콘에 `<<abstract>>` 표기)는 객체 생성 불가능
#
# ---
#
# ### 2. **라이브러리 클래스 객체 생성 방법**
# 1. 메뉴에서 **Tools → Use Libraries Class** 선택
# 2. 팝업 대화상자에 **패키지 이름 포함 전체 클래스명** 입력 (예: `java.lang.String`)
#    - 최근 사용 클래스 목록은 텍스트 필드에서 확인 가능
# 3. **Enter 버튼** 누름 → 생성자/정적 메소드 리스트 표시
# 4. 원하는 생성자 또는 정적 메소드 선택 후 실행
#    - 라이브러리 객체도 오브젝트 벤치에 생성됨
#
# ---
#
# ### 3. **정적 메소드(main 메소드) 호출 방법**
# 1. 클래스 아이콘에서 **마우스 오른쪽 버튼 클릭**
# 2. 팝업 메뉴에서 **정적 메소드** (예: `main(String[] args)`) 선택
# 3. 매개변수가 필요한 경우 **배열 상수 형식**으로 입력 (예: `{"one","two"}`)
# 4. **OK 버튼** 클릭 → 메소드 실행
#
# ---
#
# ### 요약
# - **일반 객체**: 클래스 아이콘 → 생성자 선택
# - **라이브러리 객체**: `Tools → Use Libraries Class` → 클래스명 입력
# - **정적 메소드**: 클래스 메뉴에서 직접 호출
#
# > 문서에서 언급되지 않은 추가 기능(예: 디버깅)은 "문서에서 찾을 수 없습니다"로 답변드립니다.
#
#  참조 문서:
#    1. 페이지 1: 3.1. BlueJ 시작하기 ············································· ··················...
#    2. 페이지 35: 3610.6. 라이브러리 클래스로부터 객체생성하기 BlueJ 는 JDK에서 제공하는 라이브러리의 클래스들로부터 객체를 생성하기 위한 기능을  제...
#    3. 페이지 7: 83.2. 프로젝트 열기 프로젝트란, 관련 있는 여러개의 파일들을 묶어서 관리하기 위한 하나의 작업 단위를 말합니다.  BlueJ  프로젝트는 ...
#
# ----------------------------------------
#
# 【테스트 2/5】
#  질문: 컴파일 오류가 발생했을 때 어떻게 확인할 수 있나요?
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# 문서 내용에 따르면, BlueJ에서 컴파일 오류를 확인하는 방법은 다음과 같습니다:
#
# 1. **에디터 창에서 직접 확인**
#    - 컴파일 시 오류가 발생한 경우, 해당 소스 코드 라인이 **반전 표시**됩니다.
#    - 에디터 하단의 **정보창(information area)**에 구체적인 오류 메시지가 출력됩니다.
#    - 예: 세미콜론(`;`) 누락 시 해당 라인과 함께 오류 메시지 표시.
#
# 2. **도움말 활용**
#    - 정보창 오른쪽의 **물음표(?) 아이콘**을 클릭하면, 해당 오류 메시지에 대한 추가 설명을 확인할 수 있습니다(문서 그림 8 참조).
#    - *주의: 모든 오류에 도움말이 제공되지는 않습니다.*
#
# 3. **프로젝트 툴바 컴파일 시**
#    - 여러 클래스를 수정한 후 프로젝트 윈도우의 **Compile 버튼**을 눌러 전체 프로젝트를 컴파일할 수 있습니다.
#    - 오류 발생 시, 해당 클래스의 에디터가 자동으로 열리며 오류 위치와 메시지가 표시됩니다.
#    - *참고: 수정된 클래스는 프로젝트 윈도우에서 **체크 표시**로 구분됩니다.*
#
# 4. **오브젝트 벤치 확인**
#    - 컴파일 오류로 인해 클래스 구현이 변경되면, **오브젝트 벤치의 모든 객체가 사라집니다**.
#    - 이는 컴파일이 정상적으로 완료되어야 객체를 다시 생성할 수 있음을 의미합니다.
#
# 5. **저장 관련 주의사항**
#    - 소스 코드는 일반적으로 자동 저장되지만, 시스템 불안정이 우려될 경우 **Class 메뉴**에서 수동으로 저장할 수 있습니다.
#
# > ✅ **요약**:
# > 1) 에디터 창에서 반전된 라인과 정보창의 메시지 확인
# > 2) 물음표(?) 아이콘으로 도움말 참조
# > 3) 프로젝트 툴바의 Compile 버튼으로 전체 검증
# > 4) 오브젝트 벤치가 비어 있는지 확인
#
#  참조 문서:
#    1. 페이지 12: 클래스를 성공적으로 컴파일 하였다면 에디터를 닫으십시오.  프로젝트 윈도우에 툴바 역시 Compile 버튼을 가지고 있습니다. 이 컴파일 기능은...
#    2. 페이지 12: 13  노트 : 프로젝트를 처음 열었을 때 왜 클래스 아이콘에 체크표시가 되어있지 않은지 궁금할 수 있습니다. people  프로젝트 내의 클래...
#    3. 페이지 1: 3.1. BlueJ 시작하기 ············································· ··················...
#
# ----------------------------------------
#
# 【테스트 3/5】
#  질문: 디버깅을 위해 중단점을 설정하는 방법을 알려주세요
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# BlueJ에서 디버깅을 위해 중단점을 설정하는 방법은 다음과 같습니다. 문서 내용을 근거로 단계별로 설명드리겠습니다.
#
# ---
#
# ### **중단점 설정 방법**
# 1. **소스 코드 열기**
#    - `examples` 디렉토리의 `debugdemo` 프로젝트를 엽니다.
#    - `Demo` 클래스를 열고, `loop` 메소드를 찾습니다.
#
# 2. **중단점 영역 확인**
#    - 편집기 창 왼쪽 여백(줄 번호 영역)에 중단점 설정 영역이 있습니다.
#      (문서 그림 13 참조: "중단점 영역")
#
# 3. **중단점 설정**
#    - `loop` 메소드의 `for` 반복문 내 **임의의 라인**을 마우스 왼쪽 버튼으로 클릭합니다.
#    - 클릭한 위치에 빨간색 "stop" 표시가 나타납니다.
#      (예: `sum += i;` 라인 등)
#
# 4. **실행 및 검증**
#    - `Demo` 클래스에서 객체를 생성한 후, `loop(10)` 메소드를 호출합니다.
#    - 프로그램 실행이 중단점에 도달하면, 해당 라인이 반전(강조)되며 디버거 창이 자동으로 열립니다.
#      (문서 그림 14 참조)
#
# ---
#
# ### **주의사항**
# - 중단점을 제거하려면 동일한 위치를 다시 클릭하면 "stop" 표시가 사라집니다.
# - 중단점은 **소스 코드의 실행 가능한 라인**에만 설정할 수 있습니다 (예: 변수 선언문, 연산문).
# - 문서에 따르면, BlueJ의 디버거는 **15분 내 설명 가능**할 정도로 간단하게 설계되었습니다.
#
# ---
#
# ### **추가 기능**
# - 디버거 창에서 **Step** 버튼으로 한 줄씩 실행하거나, **Step Into** 버튼으로 메소드 내부로 진입할 수 있습니다.
# - 변수 값은 디버거 창에서 실시간으로 확인 가능합니다 (문서 23번 항목 참조).
#
# > 문서에 명시되지 않은 다른 기능(예: 조건부 중단점)은 "문서에서 찾을 수 없습니다".
#
#  참조 문서:
#    1. 페이지 25: 267. 디버깅 이 절에서는, BlueJ의 디버깅에 관한 기능들 중에서 가장 중요한 측면을 소개합니다. 컴퓨터  프로그래밍 담당 선생님들은 첫 ...
#    2. 페이지 2: 37. 디버깅 ························································· ··············...
#    3. 페이지 25: 마우스 왼쪽 버튼으로 클릭함으로써 중단점을 설정할 수 있습니다. 작은 stop 표시가 중단점을 의미합니다. 바로 시도해 봅시다. Demo  클래...
#
# ----------------------------------------
#
# 【테스트 4/5】
#  질문: 코드패드는 무엇이고 어떻게 사용하나요?
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# ### **코드패드(Code Pad)란?**
# BlueJ의 코드패드는 **자바 코드의 일부(표현식 또는 명령문)를 실시간으로 평가**할 수 있는 도구입니다. 프로그램 실행 없이 코드의 의미를 확인하거나, 객체 생성/검사, 간단한 테스트 등을 수행할 수 있습니다.
#
# ---
#
# ### **코드패드 사용 방법 (단계별 설명)**
#
# #### **1. 코드패드 열기**
# - **메뉴 경로**: `보기 > 코드패드 보기(Show Code Pad)`를 선택합니다.
# - **위치**: BlueJ 메인 화면의 **오른쪽 하단**(오브젝트 벤치 옆)에 나타납니다.
# - **크기 조절**: 코드패드와 오브젝트 벤치 사이의 가로/세로 선을 드래그하여 크기를 조정할 수 있습니다.
#
# #### **2. 표현식 또는 명령문 입력**
# - **입력 예시**:
#   - `4 + 45` (기본 연산)
#   - `"hello".length()` (메소드 호출)
#   - `new Student()` (객체 생성)
# - **실행 방법**:
#   - **Enter 키**를 눌러 한 줄씩 실행합니다.
#   - **멀티라인 명령문**은 각 줄 끝에 `Shift + Enter`를 눌러 입력 후, 마지막 줄에서 `Enter`로 실행합니다.
#     - 예:
#       ```java
#       int sum = 0;
#       sum += 10;
#       sum
#       ```
#
# #### **3. 결과 확인**
# - **출력 형식**:
#   - 결과값과 함께 **타입**이 괄호 안에 표시됩니다. (예: `50 (int)`)
#   - 객체 생성 시 `<object reference>`와 클래스명이 표시되며, **작은 객체 아이콘**이 나타납니다.
# - **에러 처리**: 잘못된 표현식 입력 시 에러 메시지가 출력됩니다.
#
# #### **4. 객체 활용 방법**
# - **오브젝트 벤치로 이동**:
#   - 코드패드의 **객체 아이콘**을 드래그하여 오브젝트 벤치로 옮깁니다.
#   - 이후 팝업 메뉴 또는 코드패드에서 메소드를 호출할 수 있습니다.
# - **객체 검사**:
#   - 코드패드의 **객체 아이콘을 더블클릭**하면 객체 상태 검사 화면이 열립니다.
#
# #### **5. 입력 이력 관리**
# - **상하 화살표 키**로 이전 입력 내용을 재사용하거나 수정할 수 있습니다.
#
# ---
#
# ### **주의사항**
# - **지역변수 범위**:
#   - 각 줄은 독립적으로 처리되므로, 한 줄에서 선언된 변수는 다른 줄에서 사용할 수 없습니다.
#   - 예: `int x = 5;`와 `x + 3`을 별도 줄에 입력하면 에러 발생.
# - **인스턴스 필드 참조**:
#   - 오브젝트 벤치의 객체는 인스턴스 필드로 간주되지만, 코드패드에서 새 필드를 정의할 수 없습니다.
#
# ---
#
# ### **예시 시나리오**
# 1. `new Student()`를 입력하고 **Enter**를 눌러 객체 생성.
# 2. 결과 아이콘에서 **마우스 오른쪽 클릭** → `getName()` 같은 메소드 호출.
# 3. 생성된 객체를 **드래그**하여 오브젝트 벤치에 추가.
# 4. 오브젝트 벤치의 객체 팝업 메뉴에서 `edit object`로 상태 확인.
#
# > 문서에서 찾을 수 없는 정보는 포함하지 않았습니다.
#
#  참조 문서:
#    1. 페이지 1: 5.2. 클래스 만들기 ················································ ··················...
#    2. 페이지 20: 216. 코드패드의 사용 BlueJ 코드패드는 자바 코드(표현식과 명령문)의 일부분을 쉽고 빠르게 평가할 수 있는 기능을  제공합니다. 따라서,...
#    3. 페이지 36: 15. 코드패드로부터 객체를 오브젝트 벤치로 이동하기 위해서는 객체아이콘을 드래그 하십시오. 16. 코드패드에서 생성된 객체를 검사하기 위해서는...
#
# ----------------------------------------
#
# 【테스트 5/5】
#  질문: 애플릿을 만들고 실행하는 방법을 설명해주세요
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# ### 애플릿 만들기 및 실행 방법 (BlueJ 기준)
#
# #### 1. **애플릿 만들기**
# 1. **새 클래스 생성**
#    - BlueJ 메인 화면에서 **`New Class`** 버튼을 클릭합니다.
#    - 대화상자에서 클래스 이름을 입력한 후, **타입(Type)** 드롭다운 메뉴에서 **`Applet`**을 선택합니다.
#    - **`OK`**를 클릭하여 애플릿 기본 골격을 생성합니다.
#      - 생성된 코드에는 `paint()` 메서드에 샘플 코드가 포함되어 있습니다.
#
# 2. **코드 편집**
#    - 에디터에서 애플릿 로직을 구현합니다.
#    - 주요 메서드(`init()`, `paint()`, `stop()` 등)는 주석으로 설명이 포함되어 있습니다.
#    - 사용자 정의 코드를 `paint()` 메서드 또는 필요한 부분에 추가합니다.
#
# ---
#
# #### 2. **애플릿 테스트하기 (BlueJ 내에서)**
# 1. **오브젝트 벤치에서 객체 생성**
#    - 클래스 아이콘을 **`오브젝트 벤치`**로 드래그하여 애플릿 객체를 생성합니다.
#    - 팝업 메뉴에서 생성자 또는 특정 메서드를 호출해 부분적으로 테스트할 수 있습니다.
#      - *주의: 애플릿은 완전히 실행되지 않으며, 개별 메서드만 테스트 가능합니다.*
#
# 2. **디버깅 제한 사항**
#    - BlueJ의 중단점(Breakpoint)은 애플릿 뷰어/브라우저에서 무시됩니다.
#    - 디버깅이 필요한 경우 **`AppletWindow`** 클래스를 별도로 사용해야 합니다.
#      - 이 클래스는 BlueJ 공식 홈페이지의 **Resources** 메뉴에서 다운로드할 수 있습니다.
#
# ---
#
# #### 3. **애플릿 실행하기**
# 1. **Run Applet 메뉴 사용**
#    - 애플릿 클래스 아이콘에서 마우스 오른쪽 버튼을 클릭해 **팝업 메뉴**를 엽니다.
#    - **`Run Applet`**을 선택합니다.
#      - 실행 방식 선택 대화상자가 나타납니다:
#        - **애플릿 뷰어** 또는 **웹 브라우저**에서 실행 가능.
#        - 웹페이지만 생성할 수도 있습니다.
#      - 기본 설정으로 두고 **`OK`**를 클릭하면 애플릿 뷰어가 실행됩니다.
#        - 애플릿 뷰어는 JDK와 동일한 버전의 JVM을 사용하므로 호환성 문제가 적습니다.
#
# 2. **예제 프로젝트 활용**
#    - 문서 내 예제 프로젝트 **`appletdemo`** (클래스: `CaseConverter`)를 열어 실습할 수 있습니다.
#    - 프로젝트 오픈 후 **`Run Applet`**을 실행해 결과를 확인합니다.
#
# ---
#
# #### 4. **추가 참고 사항**
# - **브라우저 실행 시 주의점**:
#   - 일부 브라우저는 다른 버전의 JVM을 사용할 수 있어 호환성 문제가 발생할 수 있습니다.
# - **독립형 어플리케이션과의 차이**:
#   - 애플릿은 웹 환경에서 실행되도록 설계되었으며, `main()` 메서드가 없습니다.
#
# > 문서에 명시되지 않은 내용(예: `AppletWindow` 사용 세부 단계)은 **"문서에서 찾을 수 없습니다"**로 답변합니다.
#
#  참조 문서:
#    1. 페이지 32: 33마이크로소프트 윈도우즈나 MAC OS시스템에서, BlueJ 는 여러분의 기본 브라우저를 사용 합니다. 유닉스 시스템의 경우는, BlueJ 설...
#    2. 페이지 31: 329. 애플릿 만들기 9.1. 애플릿 실행하기     BuleJ 는 어플리케이션 뿐만 아니라 애플릿을 만들고, 실행할 수 있습니다. 예제(ex...
#    3. 페이지 2: 8. 독립형 어플리케이션 생성 ··············································· ···············...
#
# ----------------------------------------

# %%
from langchain_upstage import UpstageGroundednessCheck

groundedness_check = UpstageGroundednessCheck()

question = "BlueJ에서 객체를 생성하는 방법은 무엇인가요?"

retrieved_docs = retriever.invoke(question)
context = "\n\n".join([doc.page_content for doc in retrieved_docs])
#print(context)

response = llm.invoke(f"{question} 관련 정보: {context}")

request_input = {
    "context": context,
    "answer": response.content
}

response = groundedness_check.invoke(request_input)
print(response)
# Out:
# grounded
